# %%
import os
import numpy as np
import cv2 as cv
import h5py
import matplotlib.pyplot as plt
import keras
from keras.layers import Conv2D, MaxPool2D, CuDNNGRU, GlobalMaxPool2D, Reshape, \
concatenate, Input, TimeDistributed, Dense, BatchNormalization, SpatialDropout2D, SpatialDropout1D, Dropout, GlobalAvgPool2D, Flatten
from keras import Model
from keras.applications import Xception
import keras.backend as k
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## First Cache all the images into your Disk

# %%
vidPath=r".\data\train\train.mp4"
imgStoragePath=r".\data\train\IMG"

IMGList=[]
def write_frames():
    op_flows=[]
    frames=[]
    count=0
    vidCap=cv.VideoCapture(vidPath)
    success=True
    while success:
        if(count%1000==0) and count >0:
            print(count)
        success,frame1=vidCap.read()
        if (success == True):
            frame1=cv.cvtColor(frame1,cv.COLOR_BGR2RGB)
            frame1=cv.resize(frame1, (0,0), fx=0.5, fy=0.5) 
            name=imgStoragePath
            filename=str(count)+r".jpg"
            IMGList.append(os.path.join(name, filename))
            cv.imwrite(os.path.join(name, filename),frame1)  
            count+=1
        else:
            print("video reading completed")
            continue
    return count

Total_frames=write_frames()

# %%
print(Total_frames,' :Total Frames')

print('Size of FileList: ',len(IMGList))
# Out:
# 20400  :Total Frames
# Size of FileList:  20400

# %%
hdf5_path = r".\data\train\train.hdf5"
resize_size=(240, 320, 2)
resize_frame_size=(240, 320, 3)

'''Only use to reset dataset'''
with h5py.File(hdf5_path, "w") as f:
    f.create_dataset("frames", shape = (1, resize_frame_size[0], resize_frame_size[1], resize_frame_size[2]),
                    maxshape = (None, resize_frame_size[0], resize_frame_size[1], resize_frame_size[2]), 
                    chunks = (1, resize_frame_size[0], resize_frame_size[1], resize_frame_size[2]))
    f.create_dataset("op_flows", shape = (1, resize_size[0], resize_size[1], resize_size[2]),
                    maxshape = (None, resize_size[0], resize_size[1], resize_size[2]), 
                    chunks = (1, resize_size[0], resize_size[1], resize_size[2]))
    f.create_dataset("speeds", shape = (1,1), maxshape = (None,1))
f.close()

# %%
def write_hdf5(hdf5_path, frames, op_flows, speeds):
    with h5py.File(hdf5_path) as f:
        print(len(frames), len(op_flows), len(speeds))
        print(f["frames"], f["op_flows"], f["speeds"])
        f["frames"].resize(f["frames"].len() + len(frames), axis = 0)
        f["op_flows"].resize(f["op_flows"].len() + len(op_flows), axis = 0)
        f["speeds"].resize(f["speeds"].len() + len(speeds), axis = 0)
        f["frames"][-len(frames):] = frames
        f["op_flows"][-len(op_flows):] = op_flows
        f["speeds"][-len(speeds):] = speeds

# %% [markdown]
# ### We are preproceesing the video to combine two frames into one

# %%
def opticalFlowDense(image_current,image_next):
    image_current=np.array(image_current)
    image_next=np.array(image_current)
    
    #convert to grayscale
    gray_current=cv.cvtColor(image_current,cv.COLOR_RGB2GRAY)
    gray_next=cv.cvtColor(image_next,cv.COLOR_RGB2GRAY)
    flow=cv.calcOpticalFlowFarneback(gray_current,gray_next,None,0.5,1,15,2,5,1.3,0)
    return flow


def augment(image_current, image_next):
    brightness=np.random.uniform(0.5,1.5)
    image_current_1 = cv.cvtColor(image_current,cv.COLOR_RGB2HSV)
    image_current_1[:,:,2] = image_current_1[:,:,2]*brightness
    
    image_next_1 = cv.cvtColor(image_next,cv.COLOR_RGB2HSV)
    image_next_1[:,:,2] = image_next_1[:,:,2]*brightness
    
    image_current_1 = cv.cvtColor(image_current_1,cv.COLOR_HSV2RGB)
    image_next_1 = cv.cvtColor(image_next_1,cv.COLOR_HSV2RGB)
    #image_current_1 = cv.normalize(image_current_1, None, alpha=0, beta=1, norm_type=cv.NORM_MINMAX, dtype=cv.CV_32F)
    #image_next_1 = cv.normalize(image_next_1, None, alpha=0, beta=1, norm_type=cv.NORM_MINMAX, dtype=cv.CV_32F)
    
    return image_current_1,image_next_1

def flipimage(image_current, image_next):
    image_current=cv.flip(image_current, 1)
    image_next=cv.flip(image_next,1)
    return image_current,image_next

# %%
import csv

speeds=[]
with open(r".\data\train\train.txt") as csvfile:
    reader=csv.reader(csvfile)
    for speed in reader:
        speeds.append(speed)
        
print(len(speeds))
# Out:
# 20400

# %%
sequence_history = 2

FrameIndices=[]
SpeedIndices=[]

for j in range(0,Total_frames-sequence_history+1):
    tempFrame=[]
    for i in range(0,sequence_history):
        tempFrame.append(i+j)
    SpeedIndices.append(max(tempFrame))
    FrameIndices.append(tempFrame)

print(len(SpeedIndices))
print(Sequence_size, ': Sequence Size')

Batch_size=100
print(Batch_size,' : BatchSize')

Num_batches=int(np.ceil(Sequence_size/Batch_size))
print(Num_batches,' : Number of Batches')


All_indices=[item for item in range(0, len(FrameIndices))]
print(All_indices[-1],'Last elem')

def generate_indices(Batch_num):
    return All_indices[Batch_num*Batch_size:(Batch_num+1)*Batch_size]

#print(IMGList[FrameIndices[generate_indices(203)[-1]][1]])
print(generate_indices(203))

'''
print(FrameIndices[generate_indices(203)[-1]])
print(SpeedIndices[generate_indices(203)[-1]])
print(IMGList[FrameIndices[generate_indices(203)[-1]][1]])
'''
# Out:
# 20399
# 20399 : Sequence Size
# 100  : BatchSize
# 204  : Number of Batches
# 20398 Last elem
# [20300, 20301, 20302, 20303, 20304, 20305, 20306, 20307, 20308, 20309, 20310, 20311, 20312, 20313, 20314, 20315, 20316, 20317, 20318, 20319, 20320, 20321, 20322, 20323, 20324, 20325, 20326, 20327, 20328, 20329, 20330, 20331, 20332, 20333, 20334, 20335, 20336, 20337, 20338, 20339, 20340, 20341, 20342, 20343, 20344, 20345, 20346, 20347, 20348, 20349, 20350, 20351, 20352, 20353, 20354, 20355, 20356, 20357, 20358, 20359, 20360, 20361, 20362, 20363, 20364, 20365, 20366, 20367, 20368, 20369, 20370, 20371, 20372, 20373, 20374, 20375, 20376, 20377, 20378, 20379, 20380, 20381, 20382, 20383, 20384, 20385, 20386, 20387, 20388, 20389, 20390, 20391, 20392, 20393, 20394, 20395, 20396, 20397, 20398]
# '\nprint(FrameIndices[generate_indices(203)[-1]])\nprint(SpeedIndices[generate_indices(203)[-1]])\nprint(IMGList[FrameIndices[generate_indices(203)[-1]][1]])\n'

# %%
'''
def make_op_flow_video():
    count=0
    for batch in range(0,Num_batches):
        print(generate_indices(batch))
        indexes=generate_indices(batch)
        for i in range(0,len(indexes)-1):
            print([indexes[i],indexes[i+1]])
            
make_op_flow_video()
'''

def make_op_flow_video1():
    count=0
    for batch in range(0,Num_batches):
        #print(generate_indices(batch))
        indexes=generate_indices(batch)
        op_flows=[]
        frames=[]
        speed=[]
        for index in indexes:
            #print([indexes[i],indexes[i+1]])
            
            if(count%1000==0) and count >0:
                print(count)
            
            frame1=cv.imread(IMGList[FrameIndices[index][0]])
            frame2=cv.imread(IMGList[FrameIndices[index][1]])
            frame1=cv.cvtColor(frame1,cv.COLOR_BGR2RGB)
            frame2=cv.cvtColor(frame2,cv.COLOR_BGR2RGB)
            
            frame1,frame2=augment(frame1,frame2)
            frame1,frame2=flipimage(frame1,frame2)
            
            flow=opticalFlowDense(frame1,frame2)
            
            op_flows.append(flow)
            frames.append(np.array(frame2))
            speed.append(speeds[SpeedIndices[index]])
            count+=1
        
        frames=np.array(frames,dtype=np.uint8)
        op_flows=np.array(op_flows,dtype=np.uint8)
        speed=np.array(speed)
        speed=speed.astype(float)
        write_hdf5(hdf5_path, frames, op_flows, speed)
        
        '''
        speed.delete()
        frames.delete()
        op_flows.delete()
        '''
    
    print("Completed Video Processing")
    return count

def make_op_flow_video2():
    count=0
    for batch in range(0,Num_batches):
        #print(generate_indices(batch))
        indexes=generate_indices(batch)
        op_flows=[]
        frames=[]
        speed=[]
        for index in indexes:
            #print([indexes[i],indexes[i+1]])
            
            if(count%1000==0) and count >0:
                print(count)
            
            frame1=cv.imread(IMGList[FrameIndices[index][0]])
            frame2=cv.imread(IMGList[FrameIndices[index][1]])
            frame1=cv.cvtColor(frame1,cv.COLOR_BGR2RGB)
            frame2=cv.cvtColor(frame2,cv.COLOR_BGR2RGB)
            
            frame1,frame2=flipimage(frame1,frame2)
            
            flow=opticalFlowDense(frame1,frame2)
            
            op_flows.append(flow)
            frames.append(np.array(frame2))
            speed.append(speeds[SpeedIndices[index]])
            count+=1
        
        frames=np.array(frames,dtype=np.uint8)
        op_flows=np.array(op_flows,dtype=np.uint8)
        speed=np.array(speed)
        speed=speed.astype(float)
        write_hdf5(hdf5_path, frames, op_flows, speed)
        
        '''
        speed.delete()
        frames.delete()
        op_flows.delete()
        '''
    
    print("Completed Video Processing")
    return count


def make_op_flow_video3():
    count=0
    for batch in range(0,Num_batches):
        #print(generate_indices(batch))
        indexes=generate_indices(batch)
        op_flows=[]
        frames=[]
        speed=[]
        for index in indexes:
            #print([indexes[i],indexes[i+1]])
            
            if(count%1000==0) and count >0:
                print(count)
            
            frame1=cv.imread(IMGList[FrameIndices[index][0]])
            frame2=cv.imread(IMGList[FrameIndices[index][1]])
            frame1=cv.cvtColor(frame1,cv.COLOR_BGR2RGB)
            frame2=cv.cvtColor(frame2,cv.COLOR_BGR2RGB)
            
            frame1,frame2=augment(frame1,frame2)
            
            flow=opticalFlowDense(frame1,frame2)
            
            op_flows.append(flow)
            frames.append(np.array(frame2))
            speed.append(speeds[SpeedIndices[index]])
            count+=1
        
        frames=np.array(frames,dtype=np.uint8)
        op_flows=np.array(op_flows,dtype=np.uint8)
        speed=np.array(speed)
        speed=speed.astype(float)
        write_hdf5(hdf5_path, frames, op_flows, speed)
        
        '''
        speed.delete()
        frames.delete()
        op_flows.delete()
        '''
    
    print("Completed Video Processing")
    return count


def make_op_flow_video4():
    count=0
    for batch in range(0,Num_batches):
        #print(generate_indices(batch))
        indexes=generate_indices(batch)
        op_flows=[]
        frames=[]
        speed=[]
        for index in indexes:
            #print([indexes[i],indexes[i+1]])
            
            if(count%1000==0) and count >0:
                print(count)
            
            frame1=cv.imread(IMGList[FrameIndices[index][0]])
            frame2=cv.imread(IMGList[FrameIndices[index][1]])
            frame1=cv.cvtColor(frame1,cv.COLOR_BGR2RGB)
            frame2=cv.cvtColor(frame2,cv.COLOR_BGR2RGB)
            
            flow=opticalFlowDense(frame1,frame2)
            
            op_flows.append(flow)
            frames.append(np.array(frame2))
            speed.append(speeds[SpeedIndices[index]])
            count+=1
        
        frames=np.array(frames,dtype=np.uint8)
        op_flows=np.array(op_flows,dtype=np.uint8)
        speed=np.array(speed)
        speed=speed.astype(float)
        write_hdf5(hdf5_path, frames, op_flows, speed)
        '''
        speed.delete()
        frames.delete()
        op_flows.delete()
        '''
    print("Completed Video Processing")
    return count

# %% [markdown]
# ### Getting all things in order

# %%
print("Starting Augmentation")

print("1: Both Flip and Brightness")
count=make_op_flow_video1()
print("Complete: ",count)
# Out:
# Starting Augmentation
# 1: Both Flip and Brightness
# C:\Users\Nihar\miniconda3\envs\TensorFlow-GPU\lib\site-packages\ipykernel_launcher.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# 100 100 100
# <HDF5 dataset "frames": shape (1, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (901, 1), type "<f4">
# 1000
# 100 100 100
# <HDF5 dataset "frames": shape (1001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (1101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (1201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (1301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (1401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (1501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (1601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (1701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (1801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (1901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (1901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (1901, 1), type "<f4">
# 2000
# 100 100 100
# <HDF5 dataset "frames": shape (2001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (2101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (2201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (2301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (2401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (2501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (2601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (2701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (2801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (2901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (2901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (2901, 1), type "<f4">
# 3000
# 100 100 100
# <HDF5 dataset "frames": shape (3001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (3101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (3201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (3301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (3401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (3501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (3601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (3701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (3801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (3901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (3901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (3901, 1), type "<f4">
# 4000
# 100 100 100
# <HDF5 dataset "frames": shape (4001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (4101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (4201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (4301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (4401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (4501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (4601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (4701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (4801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (4901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (4901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (4901, 1), type "<f4">
# 5000
# 100 100 100
# <HDF5 dataset "frames": shape (5001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (5101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (5201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (5301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (5401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (5501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (5601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (5701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (5801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (5901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (5901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (5901, 1), type "<f4">
# 6000
# 100 100 100
# <HDF5 dataset "frames": shape (6001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (6101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (6201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (6301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (6401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (6501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (6601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (6701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (6801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (6901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (6901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (6901, 1), type "<f4">
# 7000
# 100 100 100
# <HDF5 dataset "frames": shape (7001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (7101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (7201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (7301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (7401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (7501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (7601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (7701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (7801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (7901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (7901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (7901, 1), type "<f4">
# 8000
# 100 100 100
# <HDF5 dataset "frames": shape (8001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (8101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (8201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (8301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (8401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (8501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (8601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (8701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (8801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (8901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (8901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (8901, 1), type "<f4">
# 9000
# 100 100 100
# <HDF5 dataset "frames": shape (9001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (9101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (9201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (9301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (9401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (9501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (9601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (9701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (9801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (9901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (9901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (9901, 1), type "<f4">
# 10000
# 100 100 100
# <HDF5 dataset "frames": shape (10001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (10101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (10201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (10301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (10401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (10501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (10601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (10701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (10801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (10901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (10901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (10901, 1), type "<f4">
# 11000
# 100 100 100
# <HDF5 dataset "frames": shape (11001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (11101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (11201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (11301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (11401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (11501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (11601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (11701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (11801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (11901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (11901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (11901, 1), type "<f4">
# 12000
# 100 100 100
# <HDF5 dataset "frames": shape (12001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (12101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (12201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (12301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (12401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (12501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (12601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (12701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (12801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (12901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (12901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (12901, 1), type "<f4">
# 13000
# 100 100 100
# <HDF5 dataset "frames": shape (13001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (13101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (13201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (13301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (13401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (13501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (13601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (13701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (13801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (13901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (13901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (13901, 1), type "<f4">
# 14000
# 100 100 100
# <HDF5 dataset "frames": shape (14001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (14101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (14201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (14301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (14401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (14501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (14601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (14701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (14801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (14901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (14901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (14901, 1), type "<f4">
# 15000
# 100 100 100
# <HDF5 dataset "frames": shape (15001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (15101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (15201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (15301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (15401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (15501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (15601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (15701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (15801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (15901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (15901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (15901, 1), type "<f4">
# 16000
# 100 100 100
# <HDF5 dataset "frames": shape (16001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (16101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (16201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (16301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (16401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (16501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (16601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (16701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (16801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (16901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (16901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (16901, 1), type "<f4">
# 17000
# 100 100 100
# <HDF5 dataset "frames": shape (17001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (17101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (17201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (17301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (17401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (17501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (17601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (17701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (17801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (17901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (17901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (17901, 1), type "<f4">
# 18000
# 100 100 100
# <HDF5 dataset "frames": shape (18001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (18101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (18201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (18301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (18401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (18501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (18601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (18701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (18801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (18901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (18901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (18901, 1), type "<f4">
# 19000
# 100 100 100
# <HDF5 dataset "frames": shape (19001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (19101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (19201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19201, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (19301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19301, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (19401, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19401, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19401, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (19501, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19501, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19501, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (19601, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19601, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19601, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (19701, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19701, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19701, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (19801, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19801, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19801, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (19901, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (19901, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (19901, 1), type "<f4">
# 20000
# 100 100 100
# <HDF5 dataset "frames": shape (20001, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20001, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20001, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (20101, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20101, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20101, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (20201, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20201, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20201, 1), type "<f4">
# 99 99 99
# <HDF5 dataset "frames": shape (20301, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20301, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20301, 1), type "<f4">
# Completed Video Processing
# Complete:  20399

# %%
print(": Flip")
count=make_op_flow_video2()
print("Complete: ",count)
# Out:
# : Flip
# C:\Users\Nihar\miniconda3\envs\TensorFlow-GPU\lib\site-packages\ipykernel_launcher.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# 100 100 100
# <HDF5 dataset "frames": shape (20400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (20500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (20600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (20700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (20800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (20900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (20900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (20900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (21000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (21100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (21200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (21300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21300, 1), type "<f4">
# 1000
# 100 100 100
# <HDF5 dataset "frames": shape (21400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (21500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (21600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (21700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (21800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (21900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (21900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (21900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (22000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (22100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (22200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (22300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22300, 1), type "<f4">
# 2000
# 100 100 100
# <HDF5 dataset "frames": shape (22400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (22500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (22600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (22700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (22800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (22900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (22900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (22900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (23000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (23100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (23200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (23300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23300, 1), type "<f4">
# 3000
# 100 100 100
# <HDF5 dataset "frames": shape (23400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (23500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (23600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (23700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (23800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (23900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (23900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (23900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (24000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (24100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (24200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (24300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24300, 1), type "<f4">
# 4000
# 100 100 100
# <HDF5 dataset "frames": shape (24400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (24500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (24600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (24700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (24800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (24900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (24900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (24900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (25000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (25100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (25200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (25300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25300, 1), type "<f4">
# 5000
# 100 100 100
# <HDF5 dataset "frames": shape (25400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (25500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (25600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (25700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (25800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (25900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (25900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (25900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (26000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (26100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (26200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (26300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26300, 1), type "<f4">
# 6000
# 100 100 100
# <HDF5 dataset "frames": shape (26400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (26500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (26600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (26700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (26800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (26900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (26900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (26900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (27000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (27100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (27200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (27300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27300, 1), type "<f4">
# 7000
# 100 100 100
# <HDF5 dataset "frames": shape (27400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (27500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (27600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (27700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (27800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (27900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (27900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (27900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (28000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (28100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (28200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (28300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28300, 1), type "<f4">
# 8000
# 100 100 100
# <HDF5 dataset "frames": shape (28400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (28500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (28600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (28700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (28800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (28900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (28900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (28900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (29000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (29100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (29200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (29300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29300, 1), type "<f4">
# 9000
# 100 100 100
# <HDF5 dataset "frames": shape (29400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (29500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (29600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (29700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (29800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (29900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (29900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (29900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (30000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (30100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (30200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (30300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30300, 1), type "<f4">
# 10000
# 100 100 100
# <HDF5 dataset "frames": shape (30400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (30500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (30600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (30700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (30800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (30900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (30900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (30900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (31000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (31100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (31200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (31300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31300, 1), type "<f4">
# 11000
# 100 100 100
# <HDF5 dataset "frames": shape (31400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (31500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (31600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (31700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (31800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (31900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (31900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (31900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (32000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (32100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (32200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (32300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32300, 1), type "<f4">
# 12000
# 100 100 100
# <HDF5 dataset "frames": shape (32400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (32500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (32600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (32700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (32800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (32900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (32900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (32900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (33000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (33100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (33200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (33300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33300, 1), type "<f4">
# 13000
# 100 100 100
# <HDF5 dataset "frames": shape (33400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (33500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (33600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (33700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (33800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (33900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (33900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (33900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (34000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (34100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (34200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (34300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34300, 1), type "<f4">
# 14000
# 100 100 100
# <HDF5 dataset "frames": shape (34400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (34500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (34600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (34700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (34800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (34900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (34900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (34900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (35000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (35100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (35200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (35300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35300, 1), type "<f4">
# 15000
# 100 100 100
# <HDF5 dataset "frames": shape (35400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (35500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (35600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (35700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (35800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (35900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (35900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (35900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (36000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (36100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (36200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (36300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36300, 1), type "<f4">
# 16000
# 100 100 100
# <HDF5 dataset "frames": shape (36400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (36500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (36600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (36700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (36800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (36900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (36900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (36900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (37000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (37100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (37200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (37300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37300, 1), type "<f4">
# 17000
# 100 100 100
# <HDF5 dataset "frames": shape (37400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (37500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (37600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (37700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (37800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (37900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (37900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (37900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (38000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (38100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (38200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (38300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38300, 1), type "<f4">
# 18000
# 100 100 100
# <HDF5 dataset "frames": shape (38400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (38500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (38600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (38700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (38800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (38900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (38900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (38900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (39000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (39100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (39200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (39300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39300, 1), type "<f4">
# 19000
# 100 100 100
# <HDF5 dataset "frames": shape (39400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (39500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (39600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39600, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (39700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39700, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (39800, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39800, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39800, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (39900, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (39900, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (39900, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (40000, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40000, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40000, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (40100, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40100, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40100, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (40200, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40200, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40200, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (40300, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40300, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40300, 1), type "<f4">
# 20000
# 100 100 100
# <HDF5 dataset "frames": shape (40400, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40400, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40400, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (40500, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40500, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40500, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (40600, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40600, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40600, 1), type "<f4">
# 99 99 99
# <HDF5 dataset "frames": shape (40700, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40700, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40700, 1), type "<f4">
# Completed Video Processing
# Complete:  20399

# %%
print("3: Brightness")
count=make_op_flow_video3()
print("Complete: ",count)
# Out:
# 3: Brightness
# C:\Users\Nihar\miniconda3\envs\TensorFlow-GPU\lib\site-packages\ipykernel_launcher.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# 100 100 100
# <HDF5 dataset "frames": shape (40799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (40899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (40999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (40999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (40999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (41099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (41199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (41299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (41399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (41499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (41599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (41699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41699, 1), type "<f4">
# 1000
# 100 100 100
# <HDF5 dataset "frames": shape (41799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (41899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (41999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (41999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (41999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (42099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (42199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (42299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (42399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (42499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (42599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (42699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42699, 1), type "<f4">
# 2000
# 100 100 100
# <HDF5 dataset "frames": shape (42799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (42899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (42999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (42999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (42999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (43099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (43199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (43299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (43399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (43499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (43599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (43699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43699, 1), type "<f4">
# 3000
# 100 100 100
# <HDF5 dataset "frames": shape (43799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (43899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (43999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (43999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (43999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (44099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (44199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (44299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (44399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (44499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (44599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (44699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44699, 1), type "<f4">
# 4000
# 100 100 100
# <HDF5 dataset "frames": shape (44799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (44899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (44999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (44999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (44999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (45099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (45199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (45299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (45399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (45499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (45599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (45699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45699, 1), type "<f4">
# 5000
# 100 100 100
# <HDF5 dataset "frames": shape (45799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (45899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (45999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (45999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (45999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (46099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (46199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (46299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (46399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (46499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (46599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (46699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46699, 1), type "<f4">
# 6000
# 100 100 100
# <HDF5 dataset "frames": shape (46799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (46899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (46999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (46999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (46999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (47099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (47199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (47299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (47399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (47499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (47599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (47699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47699, 1), type "<f4">
# 7000
# 100 100 100
# <HDF5 dataset "frames": shape (47799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (47899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (47999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (47999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (47999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (48099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (48199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (48299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (48399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (48499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (48599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (48699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48699, 1), type "<f4">
# 8000
# 100 100 100
# <HDF5 dataset "frames": shape (48799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (48899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (48999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (48999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (48999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (49099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (49199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (49299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (49399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (49499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (49599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (49699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49699, 1), type "<f4">
# 9000
# 100 100 100
# <HDF5 dataset "frames": shape (49799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (49899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (49999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (49999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (49999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (50099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (50199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (50299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (50399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (50499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (50599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (50699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50699, 1), type "<f4">
# 10000
# 100 100 100
# <HDF5 dataset "frames": shape (50799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (50899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (50999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (50999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (50999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (51099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (51199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (51299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (51399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (51499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (51599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (51699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51699, 1), type "<f4">
# 11000
# 100 100 100
# <HDF5 dataset "frames": shape (51799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (51899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (51999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (51999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (51999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (52099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (52199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (52299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (52399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (52499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (52599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (52699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52699, 1), type "<f4">
# 12000
# 100 100 100
# <HDF5 dataset "frames": shape (52799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (52899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (52999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (52999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (52999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (53099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (53199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (53299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (53399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (53499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (53599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (53699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53699, 1), type "<f4">
# 13000
# 100 100 100
# <HDF5 dataset "frames": shape (53799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (53899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (53999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (53999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (53999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (54099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (54199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (54299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (54399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (54499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (54599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (54699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54699, 1), type "<f4">
# 14000
# 100 100 100
# <HDF5 dataset "frames": shape (54799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (54899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (54999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (54999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (54999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (55099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (55199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (55299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (55399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (55499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (55599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (55699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55699, 1), type "<f4">
# 15000
# 100 100 100
# <HDF5 dataset "frames": shape (55799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (55899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (55999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (55999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (55999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (56099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (56199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (56299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (56399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (56499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (56599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (56699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56699, 1), type "<f4">
# 16000
# 100 100 100
# <HDF5 dataset "frames": shape (56799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (56899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (56999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (56999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (56999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (57099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (57199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (57299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (57399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (57499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (57599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (57699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57699, 1), type "<f4">
# 17000
# 100 100 100
# <HDF5 dataset "frames": shape (57799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (57899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (57999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (57999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (57999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (58099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (58199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (58299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (58399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (58499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (58599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (58699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58699, 1), type "<f4">
# 18000
# 100 100 100
# <HDF5 dataset "frames": shape (58799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (58899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (58999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (58999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (58999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (59099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (59199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (59299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (59399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (59499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (59599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (59699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59699, 1), type "<f4">
# 19000
# 100 100 100
# <HDF5 dataset "frames": shape (59799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (59899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (59999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (59999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (59999, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (60099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60099, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (60199, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60199, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60199, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (60299, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60299, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60299, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (60399, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60399, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60399, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (60499, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60499, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60499, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (60599, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60599, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60599, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (60699, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60699, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60699, 1), type "<f4">
# 20000
# 100 100 100
# <HDF5 dataset "frames": shape (60799, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60799, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60799, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (60899, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60899, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60899, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (60999, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (60999, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (60999, 1), type "<f4">
# 99 99 99
# <HDF5 dataset "frames": shape (61099, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61099, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61099, 1), type "<f4">
# Completed Video Processing
# Complete:  20399

# %%
print("4: None")
count=make_op_flow_video4()
print("Complete: ",count)
# Out:
# 4: None
# C:\Users\Nihar\miniconda3\envs\TensorFlow-GPU\lib\site-packages\ipykernel_launcher.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# 100 100 100
# <HDF5 dataset "frames": shape (61198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (61298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (61398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (61498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (61598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (61698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (61798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (61898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (61998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (61998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (61998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (62098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62098, 1), type "<f4">
# 1000
# 100 100 100
# <HDF5 dataset "frames": shape (62198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (62298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (62398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (62498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (62598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (62698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (62798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (62898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (62998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (62998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (62998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (63098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63098, 1), type "<f4">
# 2000
# 100 100 100
# <HDF5 dataset "frames": shape (63198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (63298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (63398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (63498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (63598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (63698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (63798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (63898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (63998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (63998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (63998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (64098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64098, 1), type "<f4">
# 3000
# 100 100 100
# <HDF5 dataset "frames": shape (64198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (64298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (64398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (64498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (64598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (64698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (64798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (64898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (64998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (64998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (64998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (65098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65098, 1), type "<f4">
# 4000
# 100 100 100
# <HDF5 dataset "frames": shape (65198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (65298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (65398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (65498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (65598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (65698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (65798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (65898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (65998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (65998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (65998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (66098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66098, 1), type "<f4">
# 5000
# 100 100 100
# <HDF5 dataset "frames": shape (66198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (66298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (66398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (66498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (66598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (66698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (66798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (66898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (66998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (66998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (66998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (67098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67098, 1), type "<f4">
# 6000
# 100 100 100
# <HDF5 dataset "frames": shape (67198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (67298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (67398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (67498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (67598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (67698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (67798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (67898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (67998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (67998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (67998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (68098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68098, 1), type "<f4">
# 7000
# 100 100 100
# <HDF5 dataset "frames": shape (68198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (68298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (68398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (68498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (68598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (68698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (68798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (68898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (68998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (68998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (68998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (69098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69098, 1), type "<f4">
# 8000
# 100 100 100
# <HDF5 dataset "frames": shape (69198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (69298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (69398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (69498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (69598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (69698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (69798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (69898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (69998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (69998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (69998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (70098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70098, 1), type "<f4">
# 9000
# 100 100 100
# <HDF5 dataset "frames": shape (70198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (70298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (70398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (70498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (70598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (70698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (70798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (70898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (70998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (70998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (70998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (71098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71098, 1), type "<f4">
# 10000
# 100 100 100
# <HDF5 dataset "frames": shape (71198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (71298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (71398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (71498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (71598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (71698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (71798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (71898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (71998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (71998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (71998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (72098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72098, 1), type "<f4">
# 11000
# 100 100 100
# <HDF5 dataset "frames": shape (72198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (72298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (72398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (72498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (72598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (72698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (72798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (72898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (72998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (72998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (72998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (73098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73098, 1), type "<f4">
# 12000
# 100 100 100
# <HDF5 dataset "frames": shape (73198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (73298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (73398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (73498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (73598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (73698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (73798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (73898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (73998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (73998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (73998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (74098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74098, 1), type "<f4">
# 13000
# 100 100 100
# <HDF5 dataset "frames": shape (74198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (74298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (74398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (74498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (74598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (74698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (74798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (74898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (74998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (74998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (74998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (75098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75098, 1), type "<f4">
# 14000
# 100 100 100
# <HDF5 dataset "frames": shape (75198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (75298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (75398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (75498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (75598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (75698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (75798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (75898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (75998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (75998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (75998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (76098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76098, 1), type "<f4">
# 15000
# 100 100 100
# <HDF5 dataset "frames": shape (76198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (76298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (76398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (76498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (76598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (76698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (76798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (76898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (76998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (76998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (76998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (77098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77098, 1), type "<f4">
# 16000
# 100 100 100
# <HDF5 dataset "frames": shape (77198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (77298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (77398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (77498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (77598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (77698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (77798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (77898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (77998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (77998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (77998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (78098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78098, 1), type "<f4">
# 17000
# 100 100 100
# <HDF5 dataset "frames": shape (78198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (78298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (78398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (78498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (78598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (78698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (78798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (78898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (78998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (78998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (78998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (79098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79098, 1), type "<f4">
# 18000
# 100 100 100
# <HDF5 dataset "frames": shape (79198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (79298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (79398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (79498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (79598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (79698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (79798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (79898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (79998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (79998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (79998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (80098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80098, 1), type "<f4">
# 19000
# 100 100 100
# <HDF5 dataset "frames": shape (80198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (80298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (80398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80398, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (80498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80498, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (80598, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80598, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80598, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (80698, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80698, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80698, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (80798, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80798, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80798, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (80898, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80898, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80898, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (80998, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (80998, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (80998, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (81098, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (81098, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (81098, 1), type "<f4">
# 20000
# 100 100 100
# <HDF5 dataset "frames": shape (81198, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (81198, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (81198, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (81298, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (81298, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (81298, 1), type "<f4">
# 100 100 100
# <HDF5 dataset "frames": shape (81398, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (81398, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (81398, 1), type "<f4">
# 99 99 99
# <HDF5 dataset "frames": shape (81498, 240, 320, 3), type "<f4"> <HDF5 dataset "op_flows": shape (81498, 240, 320, 2), type "<f4"> <HDF5 dataset "speeds": shape (81498, 1), type "<f4">
# Completed Video Processing
# Complete:  20399

# %%
import csv

speeds=[]
with open(r".\data\train\train.txt") as csvfile:
    reader=csv.reader(csvfile)
    for speed in reader:
        speeds.append(speed)
        
speeds=np.array(speeds)
frames, op_flows, count = make_op_flow_video2()

print("speed length")
print(len(speeds))

speeds=speeds[1:]
print(len(speeds),'Changed length')

speeds=speeds.astype(np.float)
write_hdf5(hdf5_path,frames,op_flows,speeds)


frames.clear()
opflows.clear()
count.clear()

# %%
import csv

speeds=[]
with open(r".\data\train\train.txt") as csvfile:
    reader=csv.reader(csvfile)
    for speed in reader:
        speeds.append(speed)
        
speeds=np.array(speeds)
frames, op_flows, count = make_op_flow_video3()

print("speed length")
print(len(speeds))

speeds=speeds[1:]
print(len(speeds),'Changed length')

speeds=speeds.astype(np.float)
write_hdf5(hdf5_path,frames,op_flows,speeds)


frames.clear()
opflows.clear()
count.clear()

# %%
import csv

speeds=[]
with open(r".\data\train\train.txt") as csvfile:
    reader=csv.reader(csvfile)
    for speed in reader:
        speeds.append(speed)
        
speeds=np.array(speeds)
frames, op_flows, count = make_op_flow_video4()

print("speed length")
print(len(speeds))

speeds=speeds[1:]
print(len(speeds),'Changed length')

speeds=speeds.astype(np.float)
write_hdf5(hdf5_path,frames,op_flows,speeds)


frames.clear()
opflows.clear()
count.clear()

# %%
def augment(image_current):
    brightness=np.random.uniform(0.5,1.5)
    image_current_1 = cv.cvtColor(image_current,cv.COLOR_RGB2HSV)
    image_current_1[:,:,2] = image_current_1[:,:,2]*brightness
    image_current_1 = cv.cvtColor(image_current_1,cv.COLOR_HSV2RGB)
    
    #image_current_1 = cv.normalize(image_current_1, None, alpha=0, beta=1, norm_type=cv.NORM_MINMAX, dtype=cv.CV_32F)
    
    return image_current_1

# %%
import random
def write_frames(augment_frames = True):
    op_flows=[]
    frames=[]
    count=0
    vidCap=cv.VideoCapture(r".\data\train\train.mp4")
    success=True
    while success:
        success,frame1=vidCap.read()
        if (success == True):
            frame1=cv.cvtColor(frame1,cv.COLOR_BGR2RGB)
            if (augment_frames == True) and (random.random()>.85):
                frame1=augment(frame1)
            name=r"C:\Users\Nihar\Documents\speedchallenge\data\train\frames"
            filename=str(count)+r".jpg"
            cv.imwrite(os.path.join(name, filename),frame1)  
            count+=1
        else:
            print("Jesus")
            print("video reading completed")
            continue

    return count

# %%
train_count=write_frames()
print(train_count,'Completed')
